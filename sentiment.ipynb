# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d5894fb1-d8fb-42bf-8650-bcf3a8755ff5" name="files[]" multiple disabled />
#      <output id="result-d5894fb1-d8fb-42bf-8650-bcf3a8755ff5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dl.zip to dl.zip

# %%
! ls
# Out:
# datalab  dl.zip  testdata.txt  training.txt

# %%
# !free -m
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:          13029         439        2201         247       10388       12094
# Swap:             0           0           0

# %%
! unzip dl.zip
# Out:
# Archive:  dl.zip
#   inflating: testdata.txt
#   inflating: training.txt

# %%
# !pip install sklearn
# Out:
# ...
# done
#   Stored in directory: /content/.cache/pip/wheels/76/03/bb/589d421d27431bcd2c6da284d5f2286c8e3b2ea3cf1594c074
# Successfully built sklearn
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import tensorflow as tf
import matplotlib.pyplot as plt
from string import punctuation
from collections import Counter
# %matplotlib inline

# %%
df=pd.read_csv('training.txt', sep='\t',names=['label','review'])

df.head()
# Out:
#    label                                             review
# 0      1            The Da Vinci Code book is just awesome.
# 1      1  this was the first clive cussler i've ever rea...
# 2      1                   i liked the Da Vinci Code a lot.
# 3      1                   i liked the Da Vinci Code a lot.
# 4      1  I liked the Da Vinci Code but it ultimatly did...

# %%
review=df.iloc[:,1].values

labels=df.iloc[:,0].values

import string

r=[]
for i in review:
  char=""
  for j in i:
    if (j.isdigit() or j in string.punctuation):
      continue
    else:
      char=char+j
    i=char
  r.append(i)

# %%
d=pd.read_csv('testdata.txt',sep='\t',names=['data'])
    

d.head()

data=d.iloc[:,0].values




l=[]
for i in data:
  char=""
  for j in i:
    if (j.isdigit() or j in string.punctuation):
      continue
    else:
      char=char+j
    i=char
  l.append(i)

# %%
l[:10]
# Out:
# [' I dont care what anyone says I like Hillary Clinton\nhave an awesome time at purdue\nYep Im still in London which is pretty awesome P Remind me to post the million and one pictures that I took when I get back to Markham\nHave to say I hate Paris Hiltons behavior but I do think shes kinda cute\ni will love the lakers\nIm so glad I love Paris Hilton too or this would be excruciating\nconsidering most Geico commericals are stupid\ni liked MIT though esp their little info book\nBefore I left Missouri I thought London was going to be so good and cool and fun and a really great experience and I was really excited\nI still like Tom Cruise\nwell i had a piece of crap toyota celica but it died in portland and i got a ford ranger\ni love angelina jolie\nI still like Tom Cruise\nUCLA is beautiful\nI think Angelina Jolie is so much more beautiful than Jennifer Anniston who by the way is majorly OVERRATED\nAngelina Jolie is beautiful\nand hondas are awesome\nI love Harvard\ni love tom cruise\n
# ...

# %%
sentences=r+l

# %%
token_sent=[]
for sentence in sentences:
  token_sent.append(sentence.lower().split())

# %%
words=[]
for i in token_sent:
  for j in i:
    words.append(j)

# %%
len(token_sent)
# Out:
# 35855

# %%
len(words)
# Out:
# 436613

# %%
words[:10]
# Out:
# ['the', 'da', 'vinci', 'code', 'book', 'is', 'just', 'awesome', 'this', 'was']

# %%
counter = Counter(words)
vocab = sorted(counter, key=counter.get, reverse=True)

# %%
vocab_to_int = {word: i for i, word in enumerate(vocab, 1)}

# %%
vocab_to_int
# Out:
# {'i': 1,
#  'the': 2,
#  'and': 3,
#  'love': 4,
#  'is': 5,
#  'a': 6,
#  'to': 7,
#  'my': 8,
#  'of': 9,
#  'that': 10,
#  'in': 11,
#  'hate': 12,
#  'like': 13,
#  'was': 14,
#  'so': 15,
#  'but': 16,
#  'awesome': 17,
#  'it': 18,
#  'stupid': 19,
#  'sucks': 20,
#  'for': 21,
#  'as': 22,
#  'at': 23,
#  'really': 24,
#  'tom': 25,
#  'potter': 26,
#  'paris': 27,
#  'harry': 28,
#  'you': 29,
#  'honda': 30,
#  'beautiful': 31,
#  'hilton': 32,
#  'san': 33,
#  'cruise': 34,
#  'boston': 35,
#  'be': 36,
#  'seattle': 37,
#  'lakers': 38,
#  'toyota': 39,
#  'da': 40,
#  'vinci': 41,
#  'ucla': 42,
#  'brokeback': 43,
#  'mountain': 44,
#  'code': 45,
#  'on': 46,
#  'london': 47,
#  'harvard': 48,
#  'have': 49,
#  'much': 50,
#  'me': 51,
#  'with': 52,
#  'angelina': 53,
#  'francisco': 54,
#  'are': 55,
#  'this': 56,
#  'because': 57,
#  'jolie': 58,
#  'im': 59,
#  'think': 60,
#  'we': 61,
#  'or': 62,
#  'too': 63,
#  'not': 64,
#  'its': 65,
#  'about': 66,
# ...

# %%
total=[]
for i in token_sent:
  for j in i:
    total.append([vocab_to_int[j] for j in i])

# %%
total
# Out:
# [[2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [56,
#   14,
#   2,
#   181,
#   3323,
#   4745,
#   109,
#   223,
#   395,
#   16,
#   103,
#   1243,
#   13,
#   4746,
#   3,
#   40,
#   41,
#   45,
#   135,
#   87,
#   4747,
#   98,
#   56],
#  [56,
#   14,
#   2,
#   181,
#   3323,
#   4745,
#   109,
#   223,
#   395,
#   16,
#   103,
#   1243,
#   13,
#   4746,
#   3,
#   40,
#   41,
#   45,
#   135,
#   87,
#   4747,
#   98,
#   56],
#  [56,
#   14,
#   2,
#   181,
#   3323,
#   4745,
#   109,
#   223,
#   395,
#   16,
#   103,
#   1243,
#   13,
#   4746,
#   3,
#   40,
#   41,
#   45,
#   135,
#   87,
#   4747,
#   98,
#   56],
#  [56,
#   14,
#   2,
#   181,
#   3323,
#   4745,
#   109,
#   223,
#   395,
#   16,
#   103,
#   1243,
#   13,
# ...

# %%
sentences[:10]
# Out:
# ['The Da Vinci Code book is just awesome',
#  'this was the first clive cussler ive ever read but even books like Relic and Da Vinci code were more plausible than this',
#  'i liked the Da Vinci Code a lot',
#  'i liked the Da Vinci Code a lot',
#  'I liked the Da Vinci Code but it ultimatly didnt seem to hold its own',
#  'thats not even an exaggeration  and at midnight we went to WalMart to buy the Da Vinci Code which is amazing of course',
#  'I loved the Da Vinci Code but now I want something better and different',
#  'i thought da vinci code was great same with kite runner',
#  'The Da Vinci Code is actually a good movie',
#  'I thought the Da Vinci Code was a pretty good book']

# %%
len(r)
# Out:
# 6918

# %%
total[:10]
# Out:
# [[2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [56,
#   14,
#   2,
#   181,
#   3323,
#   4745,
#   109,
#   223,
#   395,
#   16,
#   103,
#   1243,
#   13,
#   4746,
#   3,
#   40,
#   41,
#   45,
#   135,
#   87,
#   4747,
#   98,
#   56],
#  [56,
#   14,
#   2,
#   181,
#   3323,
#   4745,
#   109,
#   223,
#   395,
#   16,
#   103,
#   1243,
#   13,
#   4746,
#   3,
#   40,
#   41,
#   45,
#   135,
#   87,
#   4747,
#   98,
#   56]]

# %%
len(X)
# Out:
# 6918

# %%
X[:10]
# Out:
# [[2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [2, 40, 41, 45, 363, 5, 78, 17],
#  [56,
#   14,
#   2,
#   181,
#   3323,
#   4745,
#   109,
#   223,
#   395,
#   16,
#   103,
#   1243,
#   13,
#   4746,
#   3,
#   40,
#   41,
#   45,
#   135,
#   87,
#   4747,
#   98,
#   56],
#  [56,
#   14,
#   2,
#   181,
#   3323,
#   4745,
#   109,
#   223,
#   395,
#   16,
#   103,
#   1243,
#   13,
#   4746,
#   3,
#   40,
#   41,
#   45,
#   135,
#   87,
#   4747,
#   98,
#   56]]

# %%
# Out:
# [2, 40, 41, 45, 363, 5, 78, 17, 56, 14]

# %%
X=total[:len(r)]
X_test=total[len(r):]

# %%
seq_len = 250

features = np.zeros((len(X), seq_len), dtype=int)
for i, review in enumerate(X):
    features[i, -len(review):] = np.array(review)[:seq_len]
    
features_test = np.zeros((len(X_test), seq_len), dtype=int)
for i, review in enumerate(X_test):
    features_test[i, -len(review):] = np.array(review)[:seq_len]

# %%
X_train = features[:6400]
y_train = labels[:6400]

# %%
X_val = features[6400:]
y_val = labels[6400:]

# %%
# !ls
# Out:
# datalab  dl.zip  test1.npy  testdata.txt  training.txt

# %%
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM

# %%
model = Sequential()
model.add(Embedding(20000,250))
model.add(LSTM(250, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(X_train,y_train,
          batch_size=100,
          epochs=20,
          verbose=2,
          validation_data=(X_val,y_val))
# Out:
# Train on 6400 samples, validate on 518 samples
# Epoch 1/20
#  - 50s - loss: 0.5757 - acc: 0.6403 - val_loss: 0.6969 - val_acc: 0.6004
# Epoch 2/20
#  - 51s - loss: 0.5030 - acc: 0.6694 - val_loss: 0.5871 - val_acc: 0.9189
# Epoch 3/20
#  - 51s - loss: 0.4939 - acc: 0.6842 - val_loss: 0.6568 - val_acc: 0.6795
# Epoch 4/20
#  - 49s - loss: 0.4905 - acc: 0.6752 - val_loss: 0.6238 - val_acc: 0.9189
# Epoch 5/20
#  - 49s - loss: 0.4870 - acc: 0.6800 - val_loss: 0.5146 - val_acc: 1.0000
# Epoch 6/20
#  - 48s - loss: 0.4860 - acc: 0.6775 - val_loss: 0.6016 - val_acc: 0.9189
# Epoch 7/20
#  - 48s - loss: 0.4847 - acc: 0.6878 - val_loss: 0.6427 - val_acc: 0.7066
# Epoch 8/20
#  - 47s - loss: 0.4840 - acc: 0.6802 - val_loss: 0.6468 - val_acc: 0.7066
# Epoch 9/20
#  - 47s - loss: 0.4846 - acc: 0.6877 - val_loss: 0.5794 - val_acc: 0.9189
# Epoch 10/20
#  - 47s - loss: 0.4834 - acc: 0.6850 - val_loss: 0.6443 - val_acc: 0.6120
# Epoch 11/20
# ...

# %%
score = model.evaluate(X_val,y_val, verbose=0)
print('Accuracy:', score[1])
# Out:
# Accuracy: 0.918918918918919

# %%
! free -m
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:          13029       12279         174         266         575         284
# Swap:             0           0           0
